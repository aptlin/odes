# %% [markdown]
#  ### Imports

# %%
import numpy as np
from math import sqrt, log, atan2, cos, sin, pi
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from warnings import filterwarnings

filterwarnings("ignore")
get_ipython().run_line_magic("matplotlib", "inline")

# %% [markdown]
#  ### Constants

# %%
FIGURE_SIZE = (12, 9)
DPI = 200
ARG_RANGE = (-5, 5)
NUM_STEPS = 10
FINE_STEPS = 1000 * NUM_STEPS
RANGE = np.linspace(*ARG_RANGE, NUM_STEPS)
FINE_RANGE = np.linspace(*ARG_RANGE, 10 * NUM_STEPS)
POS_RANGE = np.linspace(0, ARG_RANGE[-1], FINE_STEPS)

# %% [markdown]
#  ### Utilities

# %%
def center_axes(fig):
    ax = fig.add_subplot(1, 1, 1)

    ax.spines["left"].set_position("center")
    ax.spines["bottom"].set_position("center")

    ax.spines["right"].set_color("none")
    ax.spines["top"].set_color("none")

    ax.xaxis.set_ticks_position("bottom")
    ax.yaxis.set_ticks_position("left")


def draw_the_vector_field(
    x_gradient,
    y_gradient,
    x_range,
    y_range,
    width=0.01,
    normalised=False,
    scale=1,
    centered_axes=True,
    figure_size=FIGURE_SIZE,
    dpi=DPI,
    color="#b5c7e5",
):
    X, Y = np.meshgrid(x_range, y_range)
    DX, DY = np.meshgrid(np.zeros(len(x_range)), np.zeros(len(y_range)))
    for x_idx, x_val in enumerate(x_range):
        for y_idx, y_val in enumerate(y_range):
            dx = x_gradient(x_val, y_val)
            dy = y_gradient(x_val, y_val)
            if normalised:
                norm = sqrt(dx ** 2 + dy ** 2)
                dx /= norm
                dy /= norm
            DX[y_idx][x_idx] = dx
            DY[y_idx][x_idx] = dy

    fig = plt.figure(figsize=figure_size, dpi=dpi)
    if centered_axes:
        center_axes(fig)

    plt.quiver(
        X,
        Y,
        DX,
        DY,
        angles="xy",
        color=color,
        edgecolors=("k",),
        units="x",
        width=width,
    )


def draw_the_graph(
    x_range,
    y_range,
    width=5,
    color="#ff5700",
    centered_axes=True,
    figure_size=FIGURE_SIZE,
    dpi=DPI,
):
    fig = plt.figure(figsize=figure_size, dpi=dpi)
    if centered_axes:
        center_axes(fig)
    return plt.plot(x_range, y_range, linewidth=4, color=color)

# %%
RANGE = np.linspace(-2, 2, 10)

# %% [markdown]
#  # Problem 1
#  ## Initial system of linear equations

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = X - 5 * Y
V = 2 * X - 5 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  ## Transformed system of linear equations

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = -2 * X - Y
V = X - 2 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  # Problem 2
#  ## a

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = -2 * X + Y
V = -2 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  ## b

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = 12 * X + 12 * Y
V = -9 * X - 9 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  ## c

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = -2 * X - 13 * Y
V = 2 * X  + 8 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  ## d

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:3000j]
U = 10 * X + 7 * Y
V = (-14) * X  + (-11) * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  ## e

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:3000j]
U = 5 * X + (-4) * Y
V = (3) * X  + (-2) * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  # Problem 3

# %%
width = 5
height = 10
radius = 1
S = np.arange(3, 4, 1 / (width * height))
S = S[:width*height]
S = S.reshape(height, width)
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
fig, ax = plt.subplots(height, width, sharex='col', sharey='row')
inch_step = 2.5
fig.set_size_inches(inch_step * width, inch_step * height)
for row_idx in range(height):
    for col_idx in range(width):
        s = S[row_idx, col_idx]
        U = -6 * X + (-7) * Y
        V = s * X  + 4 * Y
        graph = ax[row_idx, col_idx]
        _ = graph.streamplot(X, Y, U, V)
        graph.title.set_text(f"s = {s}")
plt.show()

# %%
radius = 0.01
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]
U = -6 * X + (-7) * Y
V =  24*X /7 + 4 * Y
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
plt.streamplot(X, Y, U, V)

# %% [markdown]
#  # Problem 4
#  ## a + c
#  ### \[-1, 1\]

# %%
radius = 1
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]

U = np.sin(X) + np.exp(Y) - 1
V = np.sin(X - Y)
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
color1 = "#ff5700"
plot1 = plt.streamplot(X, Y, U, V, color=color1)
plot1_patch = mpatches.Patch(color=color1, label="Original")

U = X + Y
V = X - Y
color2 = "#005700"
plot2 = plt.streamplot(X, Y, U, V, color=color2)
plot2_patch = mpatches.Patch(color=color2, label="Linearised")

plt.legend(handles=[plot1_patch, plot2_patch])

# %% [markdown]
#  ### \[-5, 5\]

# %%
radius = 5
Y, X = np.mgrid[-radius:radius:1000j, -radius:radius:1000j]


def x_gradient(x, y): return np.sin(x) + np.exp(y) - 1


def y_gradient(x, y): return np.sin(x - y)


U = np.vectorize(x_gradient)(X, Y)
V = np.vectorize(y_gradient)(X, Y)
fig = plt.figure(figsize=FIGURE_SIZE)
center_axes(fig)
color1 = "#ff5700"
plot1 = plt.streamplot(X, Y, U, V, color=color1)
plot1_patch = mpatches.Patch(color=color1, label="Original")

U = X + Y
V = X - Y
color2 = "#005700"
plot2 = plt.streamplot(X, Y, U, V, color=color2)
plot2_patch = mpatches.Patch(color=color2, label="Linearised")

plt.legend(handles=[plot1_patch, plot2_patch])

# %% [markdown]
#  ## d

# %%
x = 5

eps = 1e-13
dt = eps * 1e7

cur_x = eps * 1
cur_y = eps * (np.sqrt(2) - 1)
while (cur_x < x):
    cur_x, cur_y = cur_x + dt * \
        x_gradient(cur_x, cur_y), cur_y + dt * y_gradient(cur_x, cur_y)

y_sep = cur_y
print(y_sep)
# Out:
# 1.625025111789104

# %%
print("The y-value is: {:#.5g}".format(y_sep))
# Out:
# The y-value is: 1.6250

# %% [markdown]
#  ## e

# %%
offset = 1e-3

cur_x = x
cur_y = y_sep + offset

while True:
    y_error = y_gradient(cur_x, cur_y)
    x_error = x_gradient(cur_x, cur_y)
    if (y_error < eps and x_error < eps):
        break
    cur_x, cur_y = cur_x - dt * \
        x_gradient(cur_x, cur_y), cur_y - dt * y_gradient(cur_x, cur_y)

upper_x_limit = cur_x
upper_y_limit = cur_y

print(f"The point upwards tends to ({upper_x_limit}, {upper_y_limit})")

cur_x = x
cur_y = y_sep - offset

while True:
    y_error = y_gradient(cur_x, cur_y)
    x_error = x_gradient(cur_x, cur_y)
    if (y_error < eps and x_error < eps):
        break
    cur_x, cur_y = cur_x - dt * \
        x_gradient(cur_x, cur_y), cur_y - dt * y_gradient(cur_x, cur_y)

lower_x_limit = cur_x
lower_y_limit = cur_y

print(f"The point downwards tends to ({lower_x_limit}, {lower_y_limit})")
# Out:
# The point upwards tends to (-5.248839569864858, -2.1072469297377507)
# The point downwards tends to (0.9175085812767503, -2.2240841111815977)
